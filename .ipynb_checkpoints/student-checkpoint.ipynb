# %% [markdown]
# ## Final Project Submission
#
# Please fill out:
# * Student name: Sung Hoon Bae
# * Student pace: Full Time
# * Scheduled project review date/time:
# * Instructor name: James Irving
# * Blog post URL:

# %% [markdown]
# # EDA

# %%
# Import necessary libraries needed to EDA.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import json

# %%
# Importing Dataset
X = pd.read_csv('datasets/Tanzanian/training_set.csv')
y = pd.read_csv('datasets/Tanzanian/train_result.csv')

# Converts functional wells into 1 and non-functional ones into 0.
# y['status_group'] = y['status_group'].apply(lambda x: 1 if x=='functional' else 0)

# Import the data and make sure it has loaded well
X.shape

# %%
def get_percent_retained(df):
    original_length = 59400
    print(f'Original Length: {original_length}')
    print(f'Current Length: {df.shape[0]}')
    print(f'Percent Retained: {round(df.shape[0]/original_length * 100, 2)}%')

# %% [markdown]
# ## Feature Engineering Try #1

# %%
import missingno as ms
ms.matrix(X)
# Out:
# <AxesSubplot:>

# %%
X.columns
# Out:
# Index(['id', 'amount_tsh', 'date_recorded', 'funder', 'gps_height',
#        'installer', 'longitude', 'latitude', 'wpt_name', 'num_private',
#        'basin', 'subvillage', 'region', 'region_code', 'district_code', 'lga',
#        'ward', 'population', 'public_meeting', 'recorded_by',
#        'scheme_management', 'scheme_name', 'permit', 'construction_year',
#        'extraction_type', 'extraction_type_group', 'extraction_type_class',
#        'management', 'management_group', 'payment', 'payment_type',
#        'water_quality', 'quality_group', 'quantity', 'quantity_group',
#        'source', 'source_type', 'source_class', 'waterpoint_type',
#        'waterpoint_type_group'],
#       dtype='object')

# %% [markdown]
# ### Columns to drop

# %%
cols_to_drop = ['amount_tsh',
 'num_private',
 'basin',
 'subvillage',
 'region',
 'lga',
 'ward',
 'recorded_by',
 'extraction_type_group',
 'extraction_type_class',
 'payment',
 'water_quality',
 'source_type',
 'quantity_group',
 'waterpoint_type',
 'scheme_name']

# %%
X.drop(columns=cols_to_drop, inplace=True)

# %% [markdown]
# ### Takes care of datetime

# %%
X['date_recorded'] = pd.to_datetime(X['date_recorded'])
X['year_recorded'] = X['date_recorded'].apply(lambda x: x.year)
X['month_recorded'] = X['date_recorded'].apply(lambda x: x.month)
X.drop(columns=['date_recorded'], axis=1, inplace=True)

# %%
X.head()
# Out:
#       id        funder  gps_height     installer  longitude   latitude  \
# 0  69572         Roman        1390         Roman  34.938093  -9.856322
# 1   8776       Grumeti        1399       GRUMETI  34.698766  -2.147466
# 2  34310  Lottery Club         686  World vision  37.460664  -3.821329
# 3  67743        Unicef         263        UNICEF  38.486161 -11.155298
# 4  19728   Action In A           0       Artisan  31.130847  -1.825359
#
#                wpt_name  region_code  district_code  population  ...  \
# 0                  none           11              5         109  ...
# 1              Zahanati           20              2         280  ...
# 2           Kwa Mahundi           21              4         250  ...
# 3  Zahanati Ya Nanyumbu           90             63          58  ...
# 4               Shuleni           18              1           0  ...
#
#   management management_group payment_type  quality_group      quantity  \
# 0        vwc       user-group     annually           good        enough
# 1        wug       user-group    never pay           good  insufficient
# 2        vwc       user-group   per bucket           good        enough
# 3        vwc       user-group    never pay           good           dry
# 4      other            other    never pay           good      seasonal
#
#                  source source_class waterpoint_type_group year_recorded  \
# 0                spring  groundwater    communal standpipe          2011
# 1  rainwater harvesting      surface    communal standpipe          2013
# 2                   dam      surface    communal standpipe          2013
# 3           machine dbh  groundwater    communal standpipe          2013
# 4  rainwater harvesting      surface    communal standpipe          2011
#
#   month_recorded
# 0              3
# 1              3
# 2              2
# 3              1
# 4              7
#
# [5 rows x 25 columns]

# %% [markdown]
# ### wpt_name into a boolean column

# %%
# 1 if a name exists and 0 if not.
X['wpt_name'] = X['wpt_name']!='none'

# %%
X.isna().sum()
# Out:
# id                          0
# funder                   3635
# gps_height                  0
# installer                3655
# longitude                   0
# latitude                    0
# wpt_name                    0
# region_code                 0
# district_code               0
# population                  0
# public_meeting           3334
# scheme_management        3877
# permit                   3056
# construction_year           0
# extraction_type             0
# management                  0
# management_group            0
# payment_type                0
# quality_group               0
# quantity                    0
# source                      0
# source_class                0
# waterpoint_type_group       0
# year_recorded               0
# month_recorded              0
# dtype: int64

# %% [markdown]
# ## Dropping missing rows

# %%
# Dropping rows with missing values
df = pd.concat([X, y], axis=1)
df.head()
# Out:
#       id        funder  gps_height     installer  longitude   latitude  \
# 0  69572         Roman        1390         Roman  34.938093  -9.856322
# 1   8776       Grumeti        1399       GRUMETI  34.698766  -2.147466
# 2  34310  Lottery Club         686  World vision  37.460664  -3.821329
# 3  67743        Unicef         263        UNICEF  38.486161 -11.155298
# 4  19728   Action In A           0       Artisan  31.130847  -1.825359
#
#    wpt_name  region_code  district_code  population  ... payment_type  \
# 0     False           11              5         109  ...     annually
# 1      True           20              2         280  ...    never pay
# 2      True           21              4         250  ...   per bucket
# 3      True           90             63          58  ...    never pay
# 4      True           18              1           0  ...    never pay
#
#   quality_group      quantity                source source_class  \
# 0          good        enough                spring  groundwater
# 1          good  insufficient  rainwater harvesting      surface
# 2          good        enough                   dam      surface
# 3          good           dry           machine dbh  groundwater
# 4          good      seasonal  rainwater harvesting      surface
#
#   waterpoint_type_group year_recorded month_recorded     id    status_group
# 0    communal standpipe          2011              3  69572      functional
# 1    communal standpipe          2013              3   8776      functional
# 2    communal standpipe          2013              2  34310      functional
# 3    communal standpipe          2013              1  67743  non functional
# 4    communal standpipe          2011              7  19728      functional
#
# [5 rows x 27 columns]

# %%
# missing values
ms.matrix(df)
# Out:
# <AxesSubplot:>

# %%
df = drop_rows_na(df, 'public_meeting')
df = drop_rows_na(df, 'permit')

# %%
def drop_rows_na(df, col):
    indices = df[col].dropna().index
    return df.loc[indices,:]

# %%
ms.matrix(df)
# Out:
# <AxesSubplot:>

# %%
get_percent_retained(df)
# Out:
# Original Length: 59400
# Current Length: 53281
# Percent Retained: 89.7%

# %% [markdown]
# ## Cat vs Num columns

# %%
# Categorical Columns
cat_cols = X.select_dtypes('O').columns
# Numerical Columsn
num_cols = X.select_dtypes(include=['float64', 'int64']).columns

# %%
cat_cols = list(cat_cols)
num_cols = list(num_cols)

# %%
num_cols.remove('id')

# %%
num_cols
# Out:
# ['gps_height',
#  'longitude',
#  'latitude',
#  'region_code',
#  'district_code',
#  'population',
#  'construction_year',
#  'year_recorded',
#  'month_recorded']

# %% [markdown]
# # Vanilla Models

# %% [markdown]
# ## Splitting Data

# %%
from sklearn.metrics import accuracy_score, auc, confusion_matrix, plot_confusion_matrix
from sklearn.model_selection import train_test_split

# %%
X = df.drop(columns=['status_group'], axis=1)
y = df['status_group']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.7, random_state=42)

# %% [markdown]
# ## Setting pipeline

# %%
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn import set_config
set_config(display='diagram')

# %%
pipe_cat = Pipeline(steps=[('imp', SimpleImputer(strategy='constant', fill_value='MISSING')),
                           ('encoder', OneHotEncoder(sparse=False, handle_unknown='ignore'))])

pipe_num = Pipeline(steps=[('imp', SimpleImputer(missing_values=0, strategy='median')),
                           ('scale', StandardScaler())])

# %%
preprocessing = ColumnTransformer(transformers=[
    ('cat', pipe_cat, cat_cols),
    ('num', pipe_num, num_cols)
])
preprocessing
# Out:
# ColumnTransformer(transformers=[('cat',
#                                  Pipeline(steps=[('imp',
#                                                   SimpleImputer(fill_value='MISSING',
#                                                                 strategy='constant')),
#                                                  ('encoder',
#                                                   OneHotEncoder(handle_unknown='ignore',
#                                                                 sparse=False))]),
#                                  ['funder', 'installer', 'public_meeting',
#                                   'scheme_management', 'permit',
#                                   'extraction_type', 'management',
#                                   'management_group', 'payment_type',
#                                   'quality_group', 'quantity', 'source',
#                                   'source_class', 'waterpoint_type_group']),
#                                 ('num',
#                                  Pipeline(steps=[('imp',
#                                                   SimpleImputer(missing_values=0,
#                                                                 strategy='median')),
#                                                  ('scale', StandardScaler())]),
#                                  ['gps_height', 'longitude', 'latitude',
#                                   'region_code', 'district_code', 'population',
#                                   'construction_year', 'year_recorded',
#                                   'month_recorded'])])

# %%
X_train_tf = preprocessing.fit_transform(X_train)
X_test_tf = preprocessing.transform(X_test)

# %%
feature_names = preprocessing.named_transformers_['cat'].\
                named_steps['encoder'].get_feature_names(cat_cols).tolist()
feature_names

features = feature_names+num_cols
# Out:
# ['funder_0',
#  'funder_A/co Germany',
#  'funder_Aar',
#  'funder_Abas Ka',
#  'funder_Abasia',
#  'funder_Abc-ihushi Development Cent',
#  'funder_Abd',
#  'funder_Abdul',
#  'funder_Abood',
#  'funder_Abs',
#  'funder_Aco/germany',
#  'funder_Acord',
#  'funder_Acord Ngo',
#  'funder_Acra',
#  'funder_Action Aid',
#  'funder_Action Contre La Faim',
#  'funder_Action In A',
#  'funder_Adap',
#  'funder_Adb',
#  'funder_Adf',
#  'funder_Adp',
#  'funder_Adp Bungu',
#  'funder_Adp Mombo',
#  'funder_Adp/w',
#  'funder_Adra',
#  'funder_Af',
#  'funder_Africa',
#  'funder_Africa Amini Alama',
#  'funder_Africa Project Ev Germany',
#  'funder_African',
#  'funder_African 2000 Network',
#  'funder_African Barrick Gold',
#  'funder_African Development Bank',
#  'funder_African Development Foundation',
#  'funder_African Muslim Agency',
#  'funder_African Realief Committe Of Ku',
#  'funder_African Reflections Foundation',
#  'funder_African Relie',
#  'funder_Africaone Ltd',
#  'funder_Africare',
#  'funder_Afriican Reli',
#  'funder_Agape Churc',
#  'funder_Agt Church',
#  'funder_Ai',
#  'funder_Aic',
#  'funder_Aic Church',
#  'funder_Aict',
#  'funder_Aimgold',
#  'funder_Amref',
#  'funder_Amrefe',
#  'funder_Anglican Church',
#  'funder_Angrikana',
#  'funder_Anjuman E Seifee',
#  'funder_Answeer Muslim Grou',
#  'funder_Apm',
#  'funder_Apm[africa Precious Metals Lt',
#  'funder_Arab Community',
#  'funder_Arabi',
#  'funder_Arabs Community',
#  'funder_Ardhi Instute',
#  'funder_Asb',
#  'funder_Asdp',
#  'funder_Asgerali N Bharwan',
#  'funder_Auwasa',
#  'funder_Awf',
#  'funder_B.A.P',
#  'funder_Ba As',
#  'funder_Babtest',
#  'funder_Babtist',
#  'funder_Bahewasa',
#  'funder_Bahresa',
#  'funder_Bakari Chimkube',
#  'funder_Bakwata',
#  'funder_Balo',
#  'funder_Bank',
#  'funder_Bao',
#  'funder_Baptist Church',
#  'funder_Baric',
#  'funder_Belgian Government',
#  'funder_Belgij',
#  'funder_Bened',
#  'funder_Benguka',
#  'funder_Bffs',
#  'funder_Bfwd',
#  'funder_Bgm',
#  'funder_Bingo Foundation',
#  'funder_Bingo Foundation Germany',
#  'funder_Bio Fuel Company',
#  'funder_Biore',
#  'funder_Boazi',
#  'funder_Bobby',
#  'funder_Bong-kug Ohh/choonlza Lee',
#  'funder_Br',
#  'funder_Bra',
#  'funder_Brdp',
#  'funder_Bread For The Wor',
#  'funder_Bread Of The Worl',
#  'funder_Bridge North',
#  'funder_British Colonial Government',
#  'funder_British Tanza',
#  'funder_Brown',
#  'funder_Bruder',
#  'funder_Bs',
#  'funder_Bsf',
#  'funder_Bukwang Church Saint',
#  'funder_Bulyahunlu Gold Mine',
#  'funder_Buptist',
#  'funder_Busoga Trust',
#  'funder_C',
#  'funder_Cafod',
#  'funder_Caltas',
#  'funder_Caltas Tanzania',
#  'funder_Caltaz Kahama',
#  'funder_Caltus',
#  'funder_Calvary Connect',
#  'funder_Camartec',
#  'funder_Camavita',
#  'funder_Canada',
#  'funder_Canada Aid',
#  'funder_Care Int',
#  'funder_Care International',
#  'funder_Caritas',
#  'funder_Cartas Tanzania',
#  'funder_Cast',
#  'funder_Cbhi',
#  'funder_Cc Motor Day 2010',
#  'funder_Ccp',
#  'funder_Ccpk',
#  'funder_Ccps',
#  'funder_Cct',
#  'funder_Cdcg',
#  'funder_Cdg',
#  'funder_Cdtf',
#  'funder_Cdtfdistrict Council',
#  'funder_Cefa',
#  'funder_Cefa-njombe',
#  'funder_Ces (gmbh)',
#  'funder_Ces(gmbh)',
#  'funder_Cg',
#  'funder_Cg/rc',
#  'funder_Ch',
#  'funder_Chai Wazir',
#  'funder_Chama Cha Ushirika',
#  'funder_Chamavita',
#  'funder_Chani',
#  'funder_Charlotte Well',
#  'funder_Cheni',
#  'funder_China Government',
#  'funder_Chmavita',
#  'funder_Christan Outrich',
#  'funder_Christian Outrich',
#  'funder_Chuo',
#  'funder_Churc',
#  'funder_Church',
#  'funder_Church Of Disciples',
#  'funder_Cida',
#  'funder_Cip',
#  'funder_Cipro/care',
#  'funder_Cipro/care/tcrs',
#  'funder_Cipro/government',
#  'funder_Clause',
#  'funder_Cmcr',
#  'funder_Cmsr',
#  'funder_Co',
#  'funder_Cobashec',
#  'funder_Cocen',
#  'funder_Cocern',
#  'funder_Cocu',
#  'funder_College',
#  'funder_Colonial Government',
#  'funder_Commu',
#  'funder_Community',
#  'funder_Compa',
#  'funder_Company',
#  'funder_Comunedi Roma',
#  'funder_Comunity Construction Fund',
#  'funder_Conce',
#  'funder_Concen',
#  'funder_Concern',
#  'funder_Concern /govern',
#  'funder_Concern World Wide',
#  'funder_Concern/governm',
#  'funder_Council',
#  'funder_Cpps',
#  'funder_Cpps Mission',
#  'funder_Cpro',
#  'funder_Craelius',
#  'funder_Cristan Outrich',
#  'funder_Csf',
#  'funder_Cspd',
#  'funder_Cvs Miss',
#  'funder_D',
#  'funder_Dadid',
#  'funder_Dadis',
#  'funder_Dads',
#  'funder_Dae Yeol And Chae Lynn',
#  'funder_Dagida',
#  'funder_Daida',
#  'funder_Dak',
#  'funder_Danida',
#  'funder_Danida /government',
#  'funder_Dar Al Ber',
#  'funder_Dar Es Salaam Round Table',
#  'funder_Dasiip',
#  'funder_Dasip',
#  'funder_Dasp',
#  'funder_Dasp Ltd',
#  'funder_Dassip',
#  'funder_Dawasa',
#  'funder_Dawasco',
#  'funder_Dbfpe',
#  'funder_Dbspe',
#  'funder_Dct',
#  'funder_Ddca',
#  'funder_Ddp',
#  'funder_De',
#  'funder_Ded',
#  'funder_Ded Kilo',
#  'funder_Ded/rwssp',
#  'funder_Denat',
#  'funder_Denish',
#  'funder_Deogratius Kasima',
#  'funder_Desk And Chair Foundation',
#  'funder_Devon Aid Korogwe',
#  'funder_Dfid',
#  'funder_Dgv',
#  'funder_Dh',
#  'funder_Dhinu',
#  'funder_Dhv',
#  'funder_Dhv Moro',
#  'funder_Dhv/gove',
#  'funder_Dhv\\norp',
#  'funder_Dimon',
#  'funder_Dioce',
#  'funder_Diocese Of Geita',
#  'funder_Diocese Of Mount Kilimanjaro',
#  'funder_District Council',
#  'funder_District Medical',
#  'funder_District Rural Project',
#  'funder_Diwani',
#  'funder_Dmdd',
#  'funder_Dmdd/solider',
#  'funder_Dmk',
#  'funder_Dmk Anglican',
#  'funder_Dmo',
#  'funder_Do',
#  'funder_Doddea',
#  'funder_Dom',
#  'funder_Domestic Rural Development Pro',
#  'funder_Domestic Water Supply Project',
#  'funder_Doner And Ded',
#  'funder_Donor',
#  'funder_Dqnida',
#  'funder_Drdp',
#  'funder_Drdp Ngo',
#  'funder_Drv Na Idara',
#  'funder_Drwssp',
#  'funder_Dsdp',
#  'funder_Dsp',
#  'funder_Duka',
#  'funder_Duwas',
#  'funder_Dw',
#  'funder_Dwe',
#  'funder_Dwe And Veo',
#  'funder_Dwe/bamboo Projec',
#  'funder_Dwe/norad',
#  'funder_Dwe/rudep',
#  'funder_Dwsdp',
#  'funder_Dwsp',
#  'funder_Dwssp',
#  'funder_Dwt',
#  'funder_Ea',
#  'funder_Eater',
#  'funder_Ebaha',
#  'funder_Education Funds',
#  'funder_Efg',
#  'funder_Egypt',
#  'funder_Egypt Government',
#  'funder_Egypt Technical Co Operation',
#  'funder_El',
#  'funder_Elct',
#  'funder_Engin',
#  'funder_Engineers Without Border',
#  'funder_Enyuati',
#  'funder_Enyueti',
#  'funder_Ereto',
#  'funder_Ermua',
#  'funder_Erre Kappa',
#  'funder_Esawa',
#  'funder_Eu',
#  'funder_Eu/acra',
#  'funder_European Union',
#  'funder_F',
#  'funder_Fabia',
#  'funder_Fao',
#  'funder_Farm Africa',
#  'funder_Farm-africa',
#  'funder_Fathe',
#  'funder_Father Bonifasi',
#  'funder_Father W',
#  'funder_Fdc',
#  'funder_Filo',
#  'funder_Fin Water',
#  'funder_Fini Water',
#  'funder_Finida German Tanzania Govt',
#  'funder_Finidagermantanzania Govt',
#  'funder_Finland',
#  'funder_Finland Government',
#  'funder_Finn Water',
#  'funder_Finw',
#  'funder_Finwater',
#  'funder_Fiwater',
#  'funder_Floresta',
#  'funder_Foreigne',
#  'funder_Fosecu',
#  'funder_Fpct',
#  'funder_Fpct Church',
#  'funder_Fpct Mulala',
#  'funder_Fptc - Pent',
#  'funder_Franc',
#  'funder_France',
#  'funder_Free Pentecoste Church Of Tanz',
#  'funder_Fresh Water Plc England',
#  'funder_Friedkin Conservation Fund',
#  'funder_Friend From Un',
#  'funder_Friends Of Kibara Foundation',
#  'funder_Friends Of Ulambo And Mwanhala',
#  'funder_Full Gospel Church',
#  'funder_Fw',
#  'funder_G.D&i.D',
#  'funder_Ga',
#  'funder_Gachuma Ginery',
#  'funder_Gaica',
#  'funder_Gain',
#  'funder_Game Fronti',
#  'funder_Gdp',
#  'funder_Geita Goldmain',
#  'funder_Gen',
#  'funder_Geochaina',
#  'funder_Gerald Tuseko Gro',
#  'funder_German Missionary',
#  'funder_Germany',
#  'funder_Germany Misionary',
#  'funder_Germany Missionary',
#  'funder_Germany Republi',
#  'funder_Gesawa',
#  'funder_Getdsc00',
#  'funder_Ggm',
#  "funder_Gil Cafe'church'",
#  'funder_Giovan Disinistra Per Salve',
#  'funder_Giz',
#  'funder_Global Fund',
#  'funder_Go',
#  'funder_Goldmain',
#  'funder_Goldwill Foundation',
#  'funder_Government',
#  'funder_Government /tassaf',
#  'funder_Government /world Vision',
#  'funder_Government And Community',
#  'funder_Government Of Tanzania',
#  'funder_Government/ Community',
#  'funder_Government/ World Bank',
#  'funder_Government/tassaf',
#  'funder_Grail Mission Kiseki Bar',
#  'funder_Grazie Franco Lucchini',
#  'funder_Greec',
#  'funder_Greinaker',
#  'funder_Greineker',
#  'funder_Grumeti',
#  'funder_Gt',
#  'funder_Gtz',
#  'funder_H',
#  'funder_H/w',
#  'funder_H4ccp',
#  'funder_Haam',
#  'funder_Halimashau',
#  'funder_Halimashauli',
#  'funder_Halmashauli',
#  'funder_Halmashaur',
#  'funder_Halmashauri',
#  'funder_Halmashauri Wil',
#  'funder_Halmashauri Ya Manispa Tabora',
#  'funder_Halmashauri Ya Wilaya',
#  'funder_Halmashauri Ya Wilaya Sikonge',
#  'funder_Ham',
#  'funder_Hamref',
#  'funder_Handeni Trunk Main(',
#  'funder_Handeni Trunk Maini',
#  'funder_Hans',
#  'funder_Hapa',
#  'funder_Hapa Singida',
#  'funder_Happy Watoto Foundation',
#  'funder_Haruna Mpog',
#  'funder_Hasawa',
#  'funder_Hasnan Murig (mbunge)',
#  'funder_Hasnein Muij Mbunge',
#  'funder_Hasnein Murij',
#  'funder_Hassan Gulam',
#  'funder_Hdv',
#  'funder_He',
#  'funder_Healt',
#  'funder_Henure Dema',
#  'funder_Heri Mission',
#  'funder_Hery',
#  'funder_Hesaw',
#  'funder_Hesawa',
#  'funder_Hesawwa',
#  'funder_Hesawz',
#  'funder_Hewasa',
#  'funder_Hewawa',
#  'funder_Hhesawa',
#  'funder_Hiap',
#  'funder_Hifab',
#  'funder_Hindu',
#  'funder_Holand',
#  'funder_Holili Water Supply',
#  'funder_Holla',
#  'funder_Holland',
#  'funder_Hongoli',
#  'funder_Hortanzia',
#  'funder_Hospital',
#  'funder_Hsw',
#  'funder_Htm',
#  'funder_Hw/rc',
#  'funder_Hydom Luthelani',
#  'funder_I Wash',
#  'funder_I.E.C',
#  'funder_Iado',
#  'funder_Icap',
#  'funder_Ics',
#  'funder_Idara Ya Maji',
#  'funder_Idc',
#  'funder_Idea',
#  'funder_Idf',
#  'funder_Idydc',
#  'funder_Ifad',
#  'funder_Ifakara',
#  'funder_Ikela Wa',
#  'funder_Ikeuchi Towels Japan',
#  'funder_Il',
#  'funder_Ilct',
#  'funder_Ilkeri Village',
#  'funder_Ilo',
#  'funder_Ilo/undp',
#  'funder_Imf',
#  'funder_In',
#  'funder_Incerto',
#  'funder_Institution',
#  'funder_Institutional',
#  'funder_Investor',
#  'funder_Iom',
#  'funder_Ir',
#  'funder_Iran Gover',
#  'funder_Irevea Sister',
#  'funder_Irevea Sister Water',
#  'funder_Irish Ai',
#  'funder_Irish Government',
#  'funder_Is',
#  'funder_Isf',
#  'funder_Isf / Tasaff',
#  'funder_Isf/government',
#  'funder_Isf/gvt',
#  'funder_Isf/tacare',
#  'funder_Isingiro Ho',
#  'funder_Islam',
#  'funder_Islamic',
#  'funder_Islamic Agency Tanzania',
#  'funder_Islamic Community',
#  'funder_Islamic Found',
#  'funder_Islamic Society',
#  'funder_Issa Mohamedi Tumwanga',
#  'funder_Italian',
#  'funder_Italy',
#  'funder_Italy Government',
#  'funder_Iucn',
#  'funder_Jacobin',
#  'funder_Jaica',
#  'funder_Jamal Abdallah',
#  'funder_Japan',
#  'funder_Japan Aid',
#  'funder_Japan Embassy',
#  'funder_Japan Food',
#  'funder_Japan Food Aid',
#  'funder_Jbg',
#  'funder_Jeica',
#  'funder_Jeshi La Wokovu',
#  'funder_Jgb',
#  'funder_Jica',
#  'funder_Jika',
#  'funder_Jimbo Fund',
#  'funder_Jimmy',
#  'funder_Jipa',
#  'funder_John Fund',
#  'funder_John Gileth',
#  'funder_John Skwese',
#  'funder_Ju',
#  "funder_Ju-sarang Church' And Bugango",
#  'funder_Judge Mchome',
#  'funder_Juhibu',
#  'funder_Jumanne Siabo',
#  'funder_Jwtz',
#  'funder_K',
#  'funder_Ka',
#  'funder_Kadip',
#  'funder_Kadp',
#  'funder_Kadres Ngo',
#  'funder_Kaemp',
#  'funder_Kagera Mine',
#  'funder_Kagunguli Secondary',
#  'funder_Kalitasi',
#  'funder_Kalitesi',
#  'funder_Kalta',
#  'funder_Kamata Project',
#  'funder_Kambi Migoko',
#  'funder_Kanamama',
#  'funder_Kanis',
#  'funder_Kanisa',
#  'funder_Kanisa Katoliki',
#  'funder_Kanisa Katoliki Lolovoni',
#  'funder_Kanisa La Menonite',
#  'funder_Kanisa La Mitume',
#  'funder_Kanisa La Neema',
#  'funder_Kanisani',
#  'funder_Kapelo',
#  'funder_Karadea Ngo',
#  'funder_Kashwas',
#  'funder_Kata',
#  'funder_Kauzeni',
#  'funder_Kayempu Ltd',
#  'funder_Kc',
#  'funder_Kcu',
#  'funder_Kdpa',
#  'funder_Kdrdp Ngo',
#  'funder_Kenyans Company',
#  'funder_Kerebuka',
#  'funder_Kfw',
#  'funder_Ki',
#  'funder_Kibaha Independent School',
#  'funder_Kibaha Town Council',
#  'funder_Kibara Foundation',
#  'funder_Kibo',
#  'funder_Kibo Brewaries',
#  'funder_Kidep',
#  'funder_Kidika',
#  'funder_Kidp',
#  'funder_Kigoma Municipal',
#  'funder_Kijij',
#  'funder_Kijiji',
#  'funder_Kikom',
#  'funder_Kikundi Cha Akina Mama',
#  'funder_Kilimarondo Parish',
#  'funder_Kilimo',
#  'funder_Kilindi District Co',
#  'funder_Kiliwater',
#  'funder_Killflora',
#  'funder_Kilol',
#  'funder_Kilomber',
#  'funder_Kilwater',
#  'funder_Kimkuma',
#  'funder_Kinapa',
#  'funder_Kindoroko Water Project',
#  'funder_Kingupira S',
#  'funder_Kirde',
#  'funder_Kirdep',
#  'funder_Kitiangare Village Community',
#  'funder_Kiuma',
#  'funder_Kiwanda Cha Samaki',
#  'funder_Kiwanda Cha Tangawizi',
#  'funder_Kizego Jumaa',
#  'funder_Kizenga',
#  'funder_Kkkt',
#  'funder_Kkkt Canal',
#  'funder_Kkkt Church',
#  'funder_Kkkt Dme',
#  'funder_Kkkt Mareu',
#  'funder_Kkkt Ndrumangeni',
#  'funder_Kkkt Usa',
#  'funder_Kkkt-dioces Ya Pare',
#  'funder_Kkkt_makwale',
#  'funder_Kmcl',
#  'funder_Koica',
#  'funder_Koico',
#  'funder_Kolopin',
#  'funder_Kombe Foundation',
#  'funder_Kome Parish',
#  'funder_Kondela',
#  'funder_Konoike',
#  'funder_Kopwe Khalifa',
#  'funder_Korea',
#  'funder_Krp',
#  'funder_Ku',
#  'funder_Kuamu',
#  'funder_Kuji Foundation',
#  'funder_Kuwait',
#  'funder_Kuwasa',
#  'funder_Kwa Ditriki Cho',
#  'funder_Kwamdulu Estate',
#  'funder_Kwang-nam Middle-school',
#  'funder_Kwik',
#  'funder_Kwikwiz',
#  'funder_Kyela Council',
#  'funder_L',
#  'funder_Lake Tanganyika',
#  'funder_Lake Tanganyika Basin',
#  'funder_Lamp',
#  'funder_Laramatak',
#  'funder_Lawate Fuka Water Suppl',
#  'funder_Lawatefuka Water Supply',
#  'funder_Lc',
#  'funder_Lcdg',
#  'funder_Lcgd',
#  'funder_Ldcgd',
#  "funder_Lee Kang Pyung's Family",
#  'funder_Lench',
#  'funder_Lench Taramai',
#  'funder_Leopad Abeid',
#  'funder_Lga',
#  'funder_Lga And Adb',
#  'funder_Lgcbg',
#  'funder_Lgcd',
#  'funder_Lgcdg',
#  'funder_Lgcgd',
#  'funder_Lgdbg',
#  'funder_Lgdcg',
#  'funder_Lidep',
#  'funder_Lifetime',
#  'funder_Lion Clu',
#  'funder_Lions',
#  'funder_Lions Club',
#  'funder_Lions Club Kilimanjaro',
#  'funder_Lips',
#  'funder_Liuwassa',
#  'funder_Livin',
#  'funder_Living Water International',
#  'funder_Liz',
#  'funder_Local',
#  'funder_Loliondo Parish',
#  'funder_Loliondo Secondary',
#  'funder_Long Ga',
#  'funder_Losaa-kia Water Supply',
#  'funder_Losakia Water Supply',
#  'funder_Lotary International',
#  'funder_Lottery',
#  'funder_Lottery Club',
#  'funder_Louise Elucas Sala',
#  'funder_Lowasa',
#  'funder_Luchelegu Primary School',
#  'funder_Luka',
#  'funder_Lungwe',
#  'funder_Lusajo',
#  'funder_Luthe',
#  'funder_Lutheran',
#  'funder_Lutheran Church',
#  'funder_Lvemp',
#  'funder_Lvia',
#  'funder_Lwf',
#  'funder_Lwi',
#  'funder_Lwi & Central Government',
#  'funder_Lwiji Italy',
#  'funder_M',
#  'funder_MISSING',
#  'funder_Ma',
#  'funder_Maajabu Pima',
#  'funder_Maashumu Mohamed',
#  'funder_Mac',
#  'funder_Machibya Guma',
#  'funder_Madra',
#  'funder_Mafwimbo',
#  'funder_Magadini Makiwaru Water',
#  'funder_Magadini-makiwaru Water',
#  'funder_Magereza',
#  'funder_Magoma Adp',
#  'funder_Magu Food Security',
#  'funder_Magul',
#  'funder_Majengo Prima',
#  'funder_Maji Mugumu',
#  'funder_Makanya Sisal Estate',
#  'funder_Makapuchini',
#  'funder_Makli',
#  'funder_Makondakonde Water Population',
#  'funder_Makonde',
#  'funder_Makonde Water Population',
#  'funder_Makonde Water Supply',
#  'funder_Makoye Masanzu',
#  'funder_Malec',
#  'funder_Maliasili',
#  'funder_Malola',
#  'funder_Mama Mery Nagu',
#  'funder_Mamad',
#  'funder_Mamlaka Ya Maji Ngara',
#  'funder_Mango Tree',
#  'funder_Manyovu Agriculture Institute',
#  'funder_Marafip',
#  'funder_Marke',
#  'funder_Marumbo Community',
#  'funder_Masai Land',
#  'funder_Mashaka',
#  'funder_Masista',
#  'funder_Maswi Drilling Co. Ltd',
#  'funder_Matata Selemani',
#  'funder_Matimbwa Sec',
#  'funder_Mavuno Ngo',
#  'funder_Maxavella',
#  'funder_Mazaro Kabula',
#  'funder_Mboma',
#  'funder_Mboni Salehe',
#  'funder_Mbozi District Council',
#  'funder_Mbozi Hospital',
#  'funder_Mbunge',
#  'funder_Mbwana Omari',
#  'funder_Mbwiro',
#  'funder_Mchukwi Hos',
#  'funder_Md',
#  'funder_Mdc',
#  'funder_Mdgwc',
#  'funder_Mdrdp',
#  'funder_Meco',
#  'funder_Medicine',
#  'funder_Meko Balo',
#  'funder_Mem',
#  'funder_Member O',
#  'funder_Member Of Parliament',
#  'funder_Menon',
#  'funder_Mfuko Wa Jimbo',
#  'funder_Mh An',
#  'funder_Mh Kapuya',
#  'funder_Mh.Chiza',
#  'funder_Mh.J S Sumari',
#  'funder_Mheza Distric Counc',
#  'funder_Mhina',
#  'funder_Mi',
#  'funder_Miab',
#  'funder_Mianz',
#  'funder_Mikumi G',
#  'funder_Milenia',
#  'funder_Mileniam Project',
#  'funder_Millenium',
#  'funder_Minis',
#  'funder_Ministry Of Education',
#  'funder_Ministry Of Healthy',
#  'funder_Ministry Of Water',
#  'funder_Minjingu',
#  'funder_Miomb',
#  'funder_Misheni',
#  'funder_Misri Government',
#  'funder_Missi',
#  'funder_Missio',
#  'funder_Mission',
#  'funder_Missionaries',
#  'funder_Missionary',
#  'funder_Mitema',
#  'funder_Miziriol',
#  'funder_Mkinga  Distric Cou',
#  'funder_Mkinga Distric Coun',
#  'funder_Mkulima',
#  'funder_Mkuyu',
#  'funder_Mmem',
#  'funder_Mnyambe',
#  'funder_Moradi',
#  'funder_Moravian',
#  'funder_Moroil',
#  'funder_Morovian',
#  'funder_Morovian Church',
#  'funder_Morrovian',
#  'funder_Moses',
#  'funder_Moshono Adp',
#  'funder_Moslem Foundation',
#  'funder_Mosque',
#  'funder_Mosqure',
#  'funder_Mow',
#  'funder_Mp',
#  'funder_Mp Mloka',
#  'funder_Mp Mzeru',
#  'funder_Ms',
#  'funder_Msabi',
#  'funder_Msf',
#  'funder_Msf/tacare',
#  'funder_Msigw',
#  'funder_Msigwa',
#  'funder_Msiki',
#  'funder_Msikiti',
#  'funder_Msikiti Masji',
#  'funder_Msikitini',
#  'funder_Mtambo',
#  'funder_Mtc',
#  'funder_Mtibwa S',
#  'funder_Mtuwasa',
#  'funder_Mtuwasa And Community',
#  'funder_Muhameid Na',
#  'funder_Municipal Council',
#  'funder_Musilim Agency',
#  'funder_Muslim Society',
#  'funder_Muslimehefen International',
#  'funder_Muslims',
#  'funder_Muslimu Society(shia)',
#  'funder_Muwsa',
#  'funder_Mwakabalula',
#  'funder_Mwakalinga',
#  'funder_Mwalimu  Maneromango Muhenzi',
#  'funder_Mwalimu Muhenza',
#  'funder_Mwalimu Omari',
#  'funder_Mwamvita Rajabu',
#  'funder_Mwanamisi Ally',
#  'funder_Mwanga Town Water Authority',
#  'funder_Mwaya Mn',
#  'funder_Mwelia Estate',
#  'funder_Mwingereza',
#  'funder_Mwinjuma Mzee',
#  'funder_Mwita Lucas',
#  'funder_Mwl. Nyerere Sec. School',
#  'funder_Mws',
#  'funder_Mzee Don',
#  'funder_Mzee Lesilali',
#  'funder_Mzee Ngwatu',
#  'funder_Mzee Omari',
#  'funder_Mzee Salum Bakari Darus',
#  'funder_Mzee Sh',
#  'funder_Mzee Shindika',
#  'funder_Mzee Smith',
#  'funder_Mzee Waziri Tajari',
#  'funder_Mzee Yassin Naya',
#  'funder_Mzinga A',
#  'funder_Mzung',
#  'funder_Mzungu Paul',
#  'funder_Nado',
#  'funder_Namungo Miners',
#  'funder_Nasan',
#  'funder_Nassan',
#  'funder_Nassor Fehed',
#  'funder_Natherland',
#  'funder_Natio',
#  'funder_National Rural',
#  'funder_National Rural (wb)',
#  'funder_National Rural And Hfa',
#  'funder_Nazalet Church',
#  'funder_Nazareth Church',
#  'funder_Ncaa',
#  'funder_Ncs',
#  'funder_Nddp',
#  'funder_Ndm',
#  'funder_Ndolezi',
#  'funder_Ndorobo Tours',
#  'funder_Ndrdp',
#  'funder_Nduku Village',
#  'funder_Neemia Mission',
#  'funder_Nethalan',
#  'funder_Nethe',
#  'funder_Netherla',
#  'funder_Netherland',
#  'funder_Netherlands',
#  'funder_Ngelepo Group',
#  'funder_Ngiresi Village Community',
#  'funder_Ngos',
#  'funder_Niger',
#  'funder_Nimrodi Mkono[mb]',
#  'funder_Nipon & Panoco',
#  'funder_Njula',
#  'funder_Nk',
#  'funder_No',
#  'funder_None',
#  'funder_Norad',
#  'funder_Norad /government',
#  'funder_Norad/ Kidep',
#  'funder_Norad/ Tassaf',
#  'funder_Norad/ Tassaf Ii',
#  'funder_Norad/japan',
#  'funder_Norad/rudep',
#  'funder_Norani',
#  'funder_Nordic',
#  'funder_Norplan',
#  'funder_Noshad',
#  'funder_Not Known',
#  'funder_Nrwssp',
#  'funder_Nsc',
#  'funder_Nssf',
#  'funder_Nwssp',
#  'funder_Nyakaho Mwita',
#  'funder_Nyamingu Subvillage',
#  'funder_Nyamongo Gold Mining',
#  'funder_Nyanza Road',
#  "funder_Oak'zion' And Bugango B' Commu",
#  'funder_Obadia',
#  'funder_Obc',
#  'funder_Oda',
#  'funder_Oikos E .Africa/european Union',
#  'funder_Oikos E.Africa/ European Union',
#  'funder_Oikos E.Africa/european Union',
#  'funder_Oikos E.Afrika',
#  'funder_Okutu Village Community',
#  'funder_Ola',
#  'funder_Old Nyika Company',
#  'funder_Oldadai Village Community',
#  'funder_Oldonyolengai',
#  'funder_Olgilai Village Community',
#  'funder_Olumuro',
#  'funder_Omar Rafael',
#  'funder_Omary Issa',
#  'funder_One Desk One Chair',
#  'funder_One Un',
#  'funder_Opec',
#  'funder_Orphanage',
#  'funder_Others',
#  'funder_Overland High School',
#  'funder_Overnment',
#  'funder_Owner Pingo C',
#  'funder_Oxfam',
#  'funder_Oxfam Gb',
#  'funder_Oxfarm',
#  'funder_Oxfarm Gb',
#  'funder_P',
#  'funder_Pad',
#  'funder_Padep',
#  'funder_Padep(mifugo)',
#  'funder_Padri',
#  'funder_Padri K',
#  'funder_Padri Matayo',
#  'funder_Pangadeco',
#  'funder_Panone',
#  'funder_Parastatal',
#  'funder_Parastatal An',
#  'funder_Partage',
#  'funder_Paskali',
#  'funder_Pataji',
#  'funder_Patrick',
#  'funder_Patuu',
#  'funder_Pci',
#  'funder_Pdi',
#  'funder_Peace Cope',
#  'funder_Pema',
#  'funder_Pentecost',
#  'funder_Pentecosta Church',
#  'funder_Pentecosta Seela',
#  'funder_Pentecostal',
#  'funder_Pentecostal Church',
#  'funder_Pentecostal Hagana Sweeden',
#  'funder_People From Japan',
#  'funder_People Of Japan',
#  'funder_People Of Sweden',
#  'funder_Perusi Bhoke',
#  'funder_Peter',
#  'funder_Peter Ngereka',
#  'funder_Peter Tesha',
#  'funder_Peters',
#  'funder_Pidp',
#  'funder_Piscope',
#  'funder_Pius Msekwa',
#  'funder_Piusi',
#  'funder_Plan Int',
#  'funder_Plan Internatio',
#  'funder_Plan International',
#  'funder_Plan Tanzania',
#  'funder_Pmo',
#  'funder_Po',
#  'funder_Poland Sec School',
#  'funder_Pori La Akiba Kigosi',
#  'funder_Pr',
#  'funder_Prf',
#  'funder_Primo Zunda',
#  'funder_Priva',
#  'funder_Private',
#  'funder_Private Individual',
#  'funder_Private Individul',
#  'funder_Private Owned',
#  'funder_Private Person',
#  'funder_Prodap',
#  'funder_Prof. Saluati',
#  'funder_Professor Ben Ohio University',
#  'funder_Pwagu',
#  'funder_Q-sem Ltd',
#  'funder_Quick',
#  'funder_Quick Wings',
#  'funder_Quick Wins',
#  'funder_Quick Wins Scheme',
#  'funder_Quicklw',
#  'funder_Quickwi',
#  'funder_Quik',
#  'funder_Quwkwin',
#  'funder_Qwekwin',
#  'funder_Qwickwin',
#  'funder_Qwiqwi',
#  'funder_R',
#  'funder_Rada',
#  'funder_Rafael Michael',
#  'funder_Rafik',
#  'funder_Railway',
#  'funder_Rajab Seleman',
#  'funder_Rajabu Athumani',
#  'funder_Rashid',
#  'funder_Rashid Mahongwe',
#  "funder_Rashid Seng'ombe",
#  'funder_Rc',
#  'funder_Rc Ch',
#  'funder_Rc Churc',
#  'funder_Rc Church',
#  'funder_Rc Church/centr',
#  'funder_Rc Missi',
#  'funder_Rc Mission',
#  'funder_Rc Missionary',
#  'funder_Rc Mofu',
#  'funder_Rc Msufi',
#  ...]

# %%
X_train_tf = pd.DataFrame(X_train_tf, columns = features)
X_test_tf = pd.DataFrame(X_test_tf, columns = features)

# %% [markdown]
# ## Random Tree Model

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier()
rf.fit(X_train_tf, y_train)
y_hat_test = rf.predict(X_test_tf)

evaluate_classification(rf, X_test_tf, y_test)
# Out:
# ------------------------------------------------------------
# [i] CLASSIFICATION REPORT
# ------------------------------------------------------------
#                          precision    recall  f1-score   support
#
#              functional       0.81      0.88      0.84      8712
# functional needs repair       0.49      0.32      0.39      1131
#          non functional       0.83      0.78      0.81      6142
#
#                accuracy                           0.80     15985
#               macro avg       0.71      0.66      0.68     15985
#            weighted avg       0.80      0.80      0.80     15985
#
# ------------------------------------------------------------
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-117-de6f782bc57e> in <module>
#       4 y_hat_test = rf.predict(X_test_tf)
#       5
# ----> 6 evaluate_classification(rf, X_test_tf, y_test)
#
# <ipython-input-115-be91d93637e2> in evaluate_classification(model, X_test, y_test, classes, normalize, cmap, label)
#      47
#      48     ## Plot Roc Curve
# ---> 49     roc_plot = metrics.plot_roc_curve(model, X_test, y_test,ax=axes[1])
#      50     axes[1].legend()
#      51     axes[1].plot([0,1],[0,1],ls=':')
#
# /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/sklearn/metrics/_plot/roc_curve.py in plot_roc_curve(estimator, X, y, sample_weight, drop_intermediate, response_method, name, ax, **kwargs)
#     188     if y_pred.ndim != 1:
#     189         if y_pred.shape[1] != 2:
# --> 190             raise ValueError(classification_error)
#     191         else:
#     192             y_pred = y_pred[:, 1]
#
# ValueError: RandomForestClassifier should be a binary classifier

# %%
import sklearn.metrics as metrics

def evaluate_classification(model,X_test,y_test,classes=None,
                           normalize='true',cmap='Purples',label=''):
    """Accepts an sklearn-compatible classification model + test data 
    and displays several sklearn.metrics functions: 
    - classifciation_report
    - plot_confusion_matrix
    - plot_roc_curve
    """
     
    ## Get Predictions
    y_hat_test = model.predict(X_test)
    
    
    ## Classification Report / Scores 
    table_header = "[i] CLASSIFICATION REPORT"
    
    ## Add Label if given
    if len(label)>0:
        table_header += f" {label}"
        
    
    ## PRINT CLASSIFICATION REPORT
    dashes = '---'*20
    print(dashes,table_header,dashes,sep='\n')

    print(metrics.classification_report(y_test,y_hat_test,
                                    target_names=classes))
    
    report = metrics.classification_report(y_test,y_hat_test,
                                               target_names=classes,
                                          output_dict=True)
    print(dashes+"\n\n")
    
    

    ## MAKE FIGURE
    fig, axes = plt.subplots(figsize=(10,4),ncols=2)
    
    ## Plot Confusion Matrix 
    metrics.plot_confusion_matrix(model, X_test,y_test,
                                  display_labels=classes,
                                  normalize=normalize,
                                 cmap=cmap,ax=axes[0])
    axes[0].set(title='Confusion Matrix')
    
    ## Plot Roc Curve
#     roc_plot = metrics.plot_roc_curve(model, X_test, y_test,ax=axes[1])
#     axes[1].legend()
#     axes[1].plot([0,1],[0,1],ls=':')
#     axes[1].grid()
#     axes[1].set_title('Receiving Operator Characteristic (ROC) Curve') 
    fig.tight_layout()
    plt.show()
    
    return report #fig,axes

# %% [markdown]
# # Feature Engineering #2

# %%
import math
def get_distance(x, y):
    pi = np.pi
    R = 6371 # Average Earth radius in km
    
    # converts to radians
    lat1 = x[0]*pi/180 
    lat2 = y[0]*pi/180
    long1 = x[1]*pi/180
    long2 = y[1]*pi/180

    # finds delta angles
    del_lat = lat1 - lat2
    del_long = long1 - long2
        
    # Source: https://www.movable-type.co.uk/
    a = np.sin(del_lat/2)**2 + np.cos(lat1)*np.cos(lat2)*np.sin(del_long/2)**2
    c = 2*np.arctan(np.sqrt(a)/np.sqrt(1-a))
    d= R*c # distance in km
        
    return d

# %%
for index, row in df.head().iterrows():
    print(index, row['latitude'], row['longitutde'])

# %%
with open('datasets/Tanzanian/TZ_state_1.geojson', 'r') as f:
    tz_states = json.load(f)

# %%
state_id_map = {}
for feature in tz_states['features']:
    feature['id'] = feature['properties']['ID_1']
    state_id_map[feature['properties']['NAME_1']] = feature['id']
state_id_map['Dar es Salaam'] = 2
state_id_map.pop('Dar-Es-Salaam')

# %%
state_id_map

# %%
df['region_id'] = df['region'].apply(lambda x: state_id_map[x])

# %%
df.keys()

# %%
sns.scatterplot(x='construction_year', y='status_group', data=df)

# %%
a = df[df['region']=='Kaskazini-Pemba']
a.shape

# %%
df['source_class'].isna().sum()

# %%
df_region = pd.DataFrame(dict(id=list(state_id_map.values()),region = list(state_id_map.keys())))
df_region

# %%
total_nums = []
total_func = []
total_repair = []
total_non_func = []

main_source = []
main_source_perc = []

quantity = []
quantity_perc = []

for region in df_region['region']:
    df_copy = df[df['region']==region].copy()
    if df_copy.shape[0] != 0:
        total_num = df_copy.shape[0]
        # Total number of wells installed in the region
        total_nums.append(total_num)

        # Total number of wells that are functions, non functional, and needs repair
        total_func.append((df_copy['status_group'] == 'functional').sum())
        total_non_func.append((df_copy['status_group'] == 'non functional').sum())
        total_repair.append((df_copy['status_group'] == 'functional needs repair').sum())

        # main water source
        try:
            main_source.append(df_copy['source_class'].value_counts(normalize=True).index[0])
            main_source_perc.append(df_copy['source_class'].value_counts(normalize=True)[0])
        except:
            print(region)

        # water quantity
        quantity.append(df_copy['quantity'].value_counts(normalize=True).index[0])
        quantity_perc.append(df_copy['quantity'].value_counts(normalize=True)[0])
    else:
        total_nums.append(0)
        total_func.append(0)
        total_non_func.append(0)
        total_repair.append(0)
        
        main_source.append(0)
        main_source_perc.append(0)
        
        quantity.append(0)
        quantity_perc.append(0)

# %%
df_region['total_nums'] = total_nums
df_region['total_func'] = total_func
df_region['total_repair'] = total_repair
df_region['total_non_func'] = total_non_func

df_region['main_source'] = main_source
df_region['main_source_perc'] = main_source_perc

df_region['quantity'] = quantity
df_region['quantity_perc'] = quantity_perc

# %%
df_region['func_perc']=round(df_region['total_func']/df_region['total_nums']*100,2)
df_region['non_func_perc']=round(df_region['total_non_func']/df_region['total_nums']*100,2)
df_region['repair_perc']=round(df_region['total_repair']/df_region['total_nums']*100,2)

# %%
df_region.dropna()

# %%
import plotly.express as px
import plotly.io as pio
pio.renderers.default = 'chrome'

# %%
px.choropleth(df_region, locations='id', 
              geojson=tz_states, 
              hover_name = 'region',
              hover_data = ['func_perc', 'non_func_perc', 'repair_perc'],
              color='total_nums',
              scope='africa')
