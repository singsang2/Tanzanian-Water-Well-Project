# %% [markdown]
# # Importing Dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
# %matplotlib inline
# Out:
# In /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The text.latex.preview rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The mathtext.fallback_to_cm rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle: Support for setting the 'mathtext.fallback_to_cm' rcParam is deprecated since 3.3 and will be removed two minor releases later; use 'mathtext.fallback : 'cm' instead.
# In /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The validate_bool_maybe_none function was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The savefig.jpeg_quality rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The keymap.all_axes rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The animation.avconv_path rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The animation.avconv_args rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.

# %%
# Importing Dataset
X = pd.read_csv('datasets/Tanzanian/training_set.csv')
y = pd.read_csv('datasets/Tanzanian/train_result.csv')

# %% [markdown]
# # Examining necessary columns

# %%
X.columns
# Out:
# Index(['id', 'amount_tsh', 'date_recorded', 'funder', 'gps_height',
#        'installer', 'longitude', 'latitude', 'wpt_name', 'num_private',
#        'basin', 'subvillage', 'region', 'region_code', 'district_code', 'lga',
#        'ward', 'population', 'public_meeting', 'recorded_by',
#        'scheme_management', 'scheme_name', 'permit', 'construction_year',
#        'extraction_type', 'extraction_type_group', 'extraction_type_class',
#        'management', 'management_group', 'payment', 'payment_type',
#        'water_quality', 'quality_group', 'quantity', 'quantity_group',
#        'source', 'source_type', 'source_class', 'waterpoint_type',
#        'waterpoint_type_group'],
#       dtype='object')

# %%
X.isna().sum()
# Out:
# id                           0
# amount_tsh                   0
# date_recorded                0
# funder                    3635
# gps_height                   0
# installer                 3655
# longitude                    0
# latitude                     0
# wpt_name                     0
# num_private                  0
# basin                        0
# subvillage                 371
# region                       0
# region_code                  0
# district_code                0
# lga                          0
# ward                         0
# population                   0
# public_meeting            3334
# recorded_by                  0
# scheme_management         3877
# scheme_name              28166
# permit                    3056
# construction_year            0
# extraction_type              0
# extraction_type_group        0
# extraction_type_class        0
# management                   0
# management_group             0
# payment                      0
# payment_type                 0
# water_quality                0
# quality_group                0
# quantity                     0
# quantity_group               0
# source                       0
# source_type                  0
# source_class                 0
# waterpoint_type              0
# waterpoint_type_group        0
# dtype: int64

# %%
# columns taht will be dropped will be added here
cols_to_drop = []

# %% [markdown]
# ## amount_tsh

# %%
# Total static head (amount water available to waterpoint)
X['amount_tsh'].plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
X['amount_tsh'].value_counts(normalize=True)
# Out:
# 0.0         0.700993
# 500.0       0.052222
# 50.0        0.041616
# 1000.0      0.025051
# 20.0        0.024630
#               ...
# 8500.0      0.000017
# 6300.0      0.000017
# 220.0       0.000017
# 138000.0    0.000017
# 12.0        0.000017
# Name: amount_tsh, Length: 98, dtype: float64

# %% [markdown]
# > 70% of the data is 0 (probability missing). Drop the column

# %%
cols_to_drop.append('amount_tsh')

# %% [markdown]
# ## date_recorded

# %%
# The date the row was entered
""" 
Change to datetime format and extact month and year to see whether there is
sort of pattern where clusters of wells do not function well
when they were recorded in certain period of time
"""
# Out:
# ' \nChange to datetime format and extact month and year to see whether there is\nsort of pattern where clusters of wells do not function well\nwhen they were recorded in certain period of time\n'

# %% [markdown]
# ## funder

# %%
# Who funded the well
X['funder'].value_counts(normalize=True)
# Out:
# Government Of Tanzania    0.162898
# Danida                    0.055841
# Hesawa                    0.039487
# Rwssp                     0.024639
# World Bank                0.024191
#                             ...
# Samsoni                   0.000018
# Water Se                  0.000018
# Mafwimbo                  0.000018
# Magige                    0.000018
# Pema                      0.000018
# Name: funder, Length: 1897, dtype: float64

# %%
X['funder'].isna().sum()/len(X['funder'])*100
# Out:
# 6.11952861952862

# %% [markdown]
# > impute using "MISSING"

# %% [markdown]
# ## wpt_name

# %%
# Name of the waterpoint if there is one
X['wpt_name'].value_counts()
# Out:
# none                  3563
# Shuleni               1748
# Zahanati               830
# Msikitini              535
# Kanisani               323
#                       ...
# Kwa Choile               1
# Kwa Hamisi Mudaha        1
# Kwa Rajabu Tumaisi       1
# Kwa Silimu               1
# Kwa Steven Moshi         1
# Name: wpt_name, Length: 37400, dtype: int64

# %% [markdown]
# > Make this into a boolean column. So checks if there is a name or not. Maybe having a name makes a difference in terms of how much people care and have a ownership of their wells.

# %%
X['wpt_name'].isna().sum()
# Out:
# 0

# %% [markdown]
# ## num_private

# %%
X['num_private'].value_counts()
# Out:
# 0      58643
# 6         81
# 1         73
# 5         46
# 8         46
#        ...
# 180        1
# 213        1
# 23         1
# 55         1
# 94         1
# Name: num_private, Length: 65, dtype: int64

# %% [markdown]
# > no information about this column was given. So it will be dropped.

# %%
cols_to_drop.append('num_private')

# %% [markdown]
# ## Geographical Locations

# %%
# The following columns are all geogrphical locations
geo_cols = ['basin', 'subvillage', 'region', 'region_code', 'district_code', 'lga', 'ward']

# %%
X[geo_cols]
# Out:
#                          basin    subvillage       region  region_code  \
# 0                   Lake Nyasa      Mnyusi B       Iringa           11
# 1                Lake Victoria       Nyamara         Mara           20
# 2                      Pangani       Majengo      Manyara           21
# 3      Ruvuma / Southern Coast    Mahakamani       Mtwara           90
# 4                Lake Victoria    Kyanyamisa       Kagera           18
# ...                        ...           ...          ...          ...
# 59395                  Pangani      Kiduruni  Kilimanjaro            3
# 59396                   Rufiji      Igumbilo       Iringa           11
# 59397                   Rufiji     Madungulu        Mbeya           12
# 59398                   Rufiji        Mwinyi       Dodoma            1
# 59399              Wami / Ruvu  Kikatanyemba     Morogoro            5
#
#        district_code             lga              ward
# 0                  5          Ludewa          Mundindi
# 1                  2       Serengeti             Natta
# 2                  4       Simanjiro           Ngorika
# 3                 63        Nanyumbu          Nanyumbu
# 4                  1         Karagwe        Nyakasimbi
# ...              ...             ...               ...
# 59395              5             Hai  Masama Magharibi
# 59396              4          Njombe            Ikondo
# 59397              7         Mbarali           Chimala
# 59398              4        Chamwino      Mvumi Makulu
# 59399              2  Morogoro Rural        Ngerengere
#
# [59400 rows x 7 columns]

# %%
len(X['lga'].unique())
# Out:
# 125

# %%
len(X['ward'].unique())
# Out:
# 2092

# %% [markdown]
# > Drop 'basin', 'subvillage', 'region', 'lga', 'ward' and leave region code and district code.

# %%
cols_to_drop += ['basin', 'subvillage', 'region', 'lga', 'ward']

# %% [markdown]
# ## population

# %%
# Population around the well
X['population'].value_counts(normalize=True)
# Out:
# 0       0.359949
# 1       0.118266
# 200     0.032660
# 150     0.031852
# 250     0.028300
#           ...
# 3241    0.000017
# 1960    0.000017
# 1685    0.000017
# 2248    0.000017
# 1439    0.000017
# Name: population, Length: 1049, dtype: float64

# %%
X['population'].isna().sum()
# Out:
# 0

# %% [markdown]
# > Even though 36% is missing data, we will first try to impute using median

# %% [markdown]
# ## recorded_by

# %%
X['recorded_by'].value_counts(normalize=True)
# Out:
# GeoData Consultants Ltd    1.0
# Name: recorded_by, dtype: float64

# %% [markdown]
# > Drop this since all the same.

# %%
cols_to_drop.append('recorded_by')

# %% [markdown]
# ## scheme_management and scheme_name

# %%
# who operates the waterpoint?
X[['scheme_management', 'scheme_name']]
# Out:
#       scheme_management                  scheme_name
# 0                   VWC                        Roman
# 1                 Other                          NaN
# 2                   VWC  Nyumba ya mungu pipe scheme
# 3                   VWC                          NaN
# 4                   NaN                          NaN
# ...                 ...                          ...
# 59395       Water Board       Losaa Kia water supply
# 59396               VWC  Ikondo electrical water sch
# 59397               VWC                          NaN
# 59398               VWC                          NaN
# 59399               VWC                          NaN
#
# [59400 rows x 2 columns]

# %%
X['scheme_management'].isna().sum(), X['scheme_name'].isna().sum()
# Out:
# (3877, 28166)

# %% [markdown]
# > Drop 'scheme_name' and impute scheme_management with 'MISSING' value.

# %%
cols_to_drop.append('scheme_name')

# %% [markdown]
# ## permit

# %%
X['permit'].value_counts(normalize=True)
# Out:
# True     0.68955
# False    0.31045
# Name: permit, dtype: float64

# %%
X['permit'].isna().sum()
# Out:
# 3056

# %% [markdown]
# > Impute using 'MISSING'

# %% [markdown]
# ## Extractions

# %%
"""
extraction_type - The kind of extraction the waterpoint uses
extraction_type_group - The kind of extraction the waterpoint uses
extraction_type_class - The kind of extraction the waterpoint uses
"""

X[['extraction_type', 'extraction_type_group', 'extraction_type_class']]
# Out:
#       extraction_type extraction_type_group extraction_type_class
# 0             gravity               gravity               gravity
# 1             gravity               gravity               gravity
# 2             gravity               gravity               gravity
# 3         submersible           submersible           submersible
# 4             gravity               gravity               gravity
# ...               ...                   ...                   ...
# 59395         gravity               gravity               gravity
# 59396         gravity               gravity               gravity
# 59397          swn 80                swn 80              handpump
# 59398     nira/tanira           nira/tanira              handpump
# 59399     nira/tanira           nira/tanira              handpump
#
# [59400 rows x 3 columns]

# %% [markdown]
# > similar columns so will just use 'extraction_type'

# %%
X['extraction_type'].isna().sum()
# Out:
# 0

# %%
cols_to_drop += ['extraction_type_group', 'extraction_type_class']

# %% [markdown]
# ## management

# %%
# how the waterpoint is managed
X[['management', 'management_group']]
# Out:
#         management management_group
# 0              vwc       user-group
# 1              wug       user-group
# 2              vwc       user-group
# 3              vwc       user-group
# 4            other            other
# ...            ...              ...
# 59395  water board       user-group
# 59396          vwc       user-group
# 59397          vwc       user-group
# 59398          vwc       user-group
# 59399          vwc       user-group
#
# [59400 rows x 2 columns]

# %%
X['management'].value_counts(normalize=True)
# Out:
# vwc                 0.681936
# wug                 0.109680
# water board         0.049377
# wua                 0.042677
# private operator    0.033182
# parastatal          0.029764
# water authority     0.015219
# other               0.014209
# company             0.011532
# unknown             0.009444
# other - school      0.001667
# trust               0.001313
# Name: management, dtype: float64

# %%
X['management_group'].value_counts(normalize=True)
# Out:
# user-group    0.883670
# commercial    0.061246
# parastatal    0.029764
# other         0.015875
# unknown       0.009444
# Name: management_group, dtype: float64

# %% [markdown]
# > keep both columns

# %% [markdown]
# ## payment

# %%
X[['payment', 'payment_type']]
# Out:
#                      payment payment_type
# 0               pay annually     annually
# 1                  never pay    never pay
# 2             pay per bucket   per bucket
# 3                  never pay    never pay
# 4                  never pay    never pay
# ...                      ...          ...
# 59395         pay per bucket   per bucket
# 59396           pay annually     annually
# 59397            pay monthly      monthly
# 59398              never pay    never pay
# 59399  pay when scheme fails   on failure
#
# [59400 rows x 2 columns]

# %% [markdown]
# > Use 'payment_type' and drop 'payment'

# %%
cols_to_drop.append('payment')

# %% [markdown]
# ## water_quality, quality_group

# %%
X[['quality_group', 'water_quality']]
# Out:
#       quality_group water_quality
# 0              good          soft
# 1              good          soft
# 2              good          soft
# 3              good          soft
# 4              good          soft
# ...             ...           ...
# 59395          good          soft
# 59396          good          soft
# 59397      fluoride      fluoride
# 59398          good          soft
# 59399         salty         salty
#
# [59400 rows x 2 columns]

# %%
X['quality_group'].value_counts(normalize=True)
# Out:
# good        0.855522
# salty       0.087458
# unknown     0.031582
# milky       0.013535
# colored     0.008249
# fluoride    0.003653
# Name: quality_group, dtype: float64

# %%
X['water_quality'].value_counts(normalize=True)
# Out:
# soft                  0.855522
# salty                 0.081751
# unknown               0.031582
# milky                 0.013535
# coloured              0.008249
# salty abandoned       0.005707
# fluoride              0.003367
# fluoride abandoned    0.000286
# Name: water_quality, dtype: float64

# %% [markdown]
# > Use 'quality_group' and drop 'water_quality'

# %%
cols_to_drop.append('water_quality')

# %% [markdown]
# ## Source

# %%
X[['source', 'source_type', 'source_class']]
# Out:
#                      source           source_type source_class
# 0                    spring                spring  groundwater
# 1      rainwater harvesting  rainwater harvesting      surface
# 2                       dam                   dam      surface
# 3               machine dbh              borehole  groundwater
# 4      rainwater harvesting  rainwater harvesting      surface
# ...                     ...                   ...          ...
# 59395                spring                spring  groundwater
# 59396                 river            river/lake      surface
# 59397           machine dbh              borehole  groundwater
# 59398          shallow well          shallow well  groundwater
# 59399          shallow well          shallow well  groundwater
#
# [59400 rows x 3 columns]

# %%
X['source'].value_counts(normalize=True)
# Out:
# spring                  0.286549
# shallow well            0.283232
# machine dbh             0.186448
# river                   0.161818
# rainwater harvesting    0.038636
# hand dtw                0.014714
# lake                    0.012879
# dam                     0.011044
# other                   0.003569
# unknown                 0.001111
# Name: source, dtype: float64

# %%
X['source_class'].value_counts(normalize=True)
# Out:
# groundwater    0.770943
# surface        0.224377
# unknown        0.004680
# Name: source_class, dtype: float64

# %% [markdown]
# > keep 'source' and 'source_class' and drop 'source_type'

# %%
cols_to_drop.append('source_type')

# %% [markdown]
# ## Quantity

# %%
X[['quantity', 'quantity_group']]
# Out:
#            quantity quantity_group
# 0            enough         enough
# 1      insufficient   insufficient
# 2            enough         enough
# 3               dry            dry
# 4          seasonal       seasonal
# ...             ...            ...
# 59395        enough         enough
# 59396        enough         enough
# 59397        enough         enough
# 59398  insufficient   insufficient
# 59399        enough         enough
#
# [59400 rows x 2 columns]

# %% [markdown]
# > drop 'quantity_group'

# %%
cols_to_drop.append('quantity_group')

# %% [markdown]
# ## waterpoint type

# %%
X[['waterpoint_type', 'waterpoint_type_group']]
# Out:
#                    waterpoint_type waterpoint_type_group
# 0               communal standpipe    communal standpipe
# 1               communal standpipe    communal standpipe
# 2      communal standpipe multiple    communal standpipe
# 3      communal standpipe multiple    communal standpipe
# 4               communal standpipe    communal standpipe
# ...                            ...                   ...
# 59395           communal standpipe    communal standpipe
# 59396           communal standpipe    communal standpipe
# 59397                    hand pump             hand pump
# 59398                    hand pump             hand pump
# 59399                    hand pump             hand pump
#
# [59400 rows x 2 columns]

# %% [markdown]
# > drop 'waterpoint_type' since group seems more general.

# %%
cols_to_drop.append('waterpoint_type')

# %% [markdown]
# # Columns to drop

# %%
cols_to_drop
# Out:
# ['amount_tsh',
#  'num_private',
#  'basin',
#  'subvillage',
#  'region',
#  'lga',
#  'ward',
#  'recorded_by',
#  'scheme_name',
#  'extraction_type_group',
#  'extraction_type_class',
#  'payment',
#  'water_quality',
#  'source_type',
#  'quantity_group',
#  'waterpoint_type']

# %%
# cols_to_drop = ['amount_tsh',
#  'num_private',
#  'basin',
#  'subvillage',
#  'region',
#  'lga',
#  'ward',
#  'recorded_by',
#  'extraction_type_group',
#  'extraction_type_class',
#  'payment',
#  'water_quality',
#  'source_type',
#  'quantity_group',
#  'waterpoint_type',
#  'scheme_name']

# %% [markdown]
# # Feature Engineering Test

# %%
df = pd.concat([X.drop(columns=cols_to_drop), y], axis=1)

# %%
# df.drop(columns='id', inplace=True)

# %%
df
# Out:
#           id date_recorded           funder  gps_height     installer  \
# 0      69572    2011-03-14            Roman        1390         Roman
# 1       8776    2013-03-06          Grumeti        1399       GRUMETI
# 2      34310    2013-02-25     Lottery Club         686  World vision
# 3      67743    2013-01-28           Unicef         263        UNICEF
# 4      19728    2011-07-13      Action In A           0       Artisan
# ...      ...           ...              ...         ...           ...
# 59395  60739    2013-05-03  Germany Republi        1210           CES
# 59396  27263    2011-05-07      Cefa-njombe        1212          Cefa
# 59397  37057    2011-04-11              NaN           0           NaN
# 59398  31282    2011-03-08            Malec           0          Musa
# 59399  26348    2011-03-23       World Bank         191         World
#
#        longitude   latitude              wpt_name  region_code  district_code  \
# 0      34.938093  -9.856322                  none           11              5
# 1      34.698766  -2.147466              Zahanati           20              2
# 2      37.460664  -3.821329           Kwa Mahundi           21              4
# 3      38.486161 -11.155298  Zahanati Ya Nanyumbu           90             63
# 4      31.130847  -1.825359               Shuleni           18              1
# ...          ...        ...                   ...          ...            ...
# 59395  37.169807  -3.253847   Area Three Namba 27            3              5
# 59396  35.249991  -9.070629     Kwa Yahona Kuvala           11              4
# 59397  34.017087  -8.750434               Mashine           12              7
# 59398  35.861315  -6.378573                Mshoro            1              4
# 59399  38.104048  -6.747464       Kwa Mzee Lugawa            5              2
#
#        ...   management management_group payment_type quality_group  \
# 0      ...          vwc       user-group     annually          good
# 1      ...          wug       user-group    never pay          good
# 2      ...          vwc       user-group   per bucket          good
# 3      ...          vwc       user-group    never pay          good
# 4      ...        other            other    never pay          good
# ...    ...          ...              ...          ...           ...
# 59395  ...  water board       user-group   per bucket          good
# 59396  ...          vwc       user-group     annually          good
# 59397  ...          vwc       user-group      monthly      fluoride
# 59398  ...          vwc       user-group    never pay          good
# 59399  ...          vwc       user-group   on failure         salty
#
#            quantity                source source_class waterpoint_type_group  \
# 0            enough                spring  groundwater    communal standpipe
# 1      insufficient  rainwater harvesting      surface    communal standpipe
# 2            enough                   dam      surface    communal standpipe
# 3               dry           machine dbh  groundwater    communal standpipe
# 4          seasonal  rainwater harvesting      surface    communal standpipe
# ...             ...                   ...          ...                   ...
# 59395        enough                spring  groundwater    communal standpipe
# 59396        enough                 river      surface    communal standpipe
# 59397        enough           machine dbh  groundwater             hand pump
# 59398  insufficient          shallow well  groundwater             hand pump
# 59399        enough          shallow well  groundwater             hand pump
#
#           id    status_group
# 0      69572      functional
# 1       8776      functional
# 2      34310      functional
# 3      67743  non functional
# 4      19728      functional
# ...      ...             ...
# 59395  60739      functional
# 59396  27263      functional
# 59397  37057      functional
# 59398  31282      functional
# 59399  26348      functional
#
# [59400 rows x 26 columns]

# %%
import math
def get_distance(x, y):
    """
    x = [lat and long]
    y = array of lat and long
    """
    pi = np.pi
    R = 6371 # Average Earth radius in km
    
    # converts to radians
    lat1 = x[0]*pi/180 
    lat2 = y.iloc[:,0]*pi/180
    long1 = x[1]*pi/180
    long2 = y.iloc[:,1]*pi/180

    # finds delta angles
    del_lat = lat1 - lat2
    del_long = long1 - long2
        
    # Source: https://www.movable-type.co.uk/
    a = np.sin(del_lat/2)**2 + np.cos(lat1)*np.cos(lat2)*np.sin(del_long/2)**2
    c = 2*np.arctan(np.sqrt(a)/np.sqrt(1-a))
    d= R*c # distance in km
        
    return d

# %%
perc_func_near = []
perc_non_func_near = []
perc_repair_near = []

for index, row in df.iterrows():
#     print(index, row['latitude'], row['longitude'])
    wp = [row['latitude'], row['longitude']]
    wps = df[['latitude', 'longitude']].copy()
    
    d = get_distance(wp, wps)
    
    distance = 50
    indices = df[d < distance].index
    
    perc_func = round(np.sum(target.iloc[indices, :] == 'functional')/len(indices)*100, 2)
    perc_non_func = round(np.sum(target.iloc[indices, :] == 'non functional')/len(indices)*100, 2)
    perc_repair_func = round(np.sum(target.iloc[indices, :] == 'functional needs repair')/len(indices)*100, 2)
    
    perc_func_near.append(perc_func[0])
    perc_non_func_near.append(perc_non_func[0])
    perc_repair_near.append(perc_repair_func[0])

# %%
target['func'] = perc_func_near
target['non_func'] = perc_non_func_near
target['repair'] = perc_repair_near

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
sns.scatterplot(x='func', y='non_func', hue='status_group', data=target)
# Out:
# <AxesSubplot:xlabel='func', ylabel='non_func'>

# %% [markdown]
# # test 2

# %%
df
# Out:
#           id  amount_tsh date_recorded           funder  gps_height  \
# 0      69572      6000.0    2011-03-14            Roman        1390
# 1       8776         0.0    2013-03-06          Grumeti        1399
# 2      34310        25.0    2013-02-25     Lottery Club         686
# 3      67743         0.0    2013-01-28           Unicef         263
# 4      19728         0.0    2011-07-13      Action In A           0
# ...      ...         ...           ...              ...         ...
# 59395  60739        10.0    2013-05-03  Germany Republi        1210
# 59396  27263      4700.0    2011-05-07      Cefa-njombe        1212
# 59397  37057         0.0    2011-04-11              NaN           0
# 59398  31282         0.0    2011-03-08            Malec           0
# 59399  26348         0.0    2011-03-23       World Bank         191
#
#           installer  longitude   latitude              wpt_name  num_private  \
# 0             Roman  34.938093  -9.856322                  none            0
# 1           GRUMETI  34.698766  -2.147466              Zahanati            0
# 2      World vision  37.460664  -3.821329           Kwa Mahundi            0
# 3            UNICEF  38.486161 -11.155298  Zahanati Ya Nanyumbu            0
# 4           Artisan  31.130847  -1.825359               Shuleni            0
# ...             ...        ...        ...                   ...          ...
# 59395           CES  37.169807  -3.253847   Area Three Namba 27            0
# 59396          Cefa  35.249991  -9.070629     Kwa Yahona Kuvala            0
# 59397           NaN  34.017087  -8.750434               Mashine            0
# 59398          Musa  35.861315  -6.378573                Mshoro            0
# 59399         World  38.104048  -6.747464       Kwa Mzee Lugawa            0
#
#        ... quality_group      quantity quantity_group                source  \
# 0      ...          good        enough         enough                spring
# 1      ...          good  insufficient   insufficient  rainwater harvesting
# 2      ...          good        enough         enough                   dam
# 3      ...          good           dry            dry           machine dbh
# 4      ...          good      seasonal       seasonal  rainwater harvesting
# ...    ...           ...           ...            ...                   ...
# 59395  ...          good        enough         enough                spring
# 59396  ...          good        enough         enough                 river
# 59397  ...      fluoride        enough         enough           machine dbh
# 59398  ...          good  insufficient   insufficient          shallow well
# 59399  ...         salty        enough         enough          shallow well
#
#                 source_type source_class              waterpoint_type  \
# 0                    spring  groundwater           communal standpipe
# 1      rainwater harvesting      surface           communal standpipe
# 2                       dam      surface  communal standpipe multiple
# 3                  borehole  groundwater  communal standpipe multiple
# 4      rainwater harvesting      surface           communal standpipe
# ...                     ...          ...                          ...
# 59395                spring  groundwater           communal standpipe
# 59396            river/lake      surface           communal standpipe
# 59397              borehole  groundwater                    hand pump
# 59398          shallow well  groundwater                    hand pump
# 59399          shallow well  groundwater                    hand pump
#
#        waterpoint_type_group     id    status_group
# 0         communal standpipe  69572      functional
# 1         communal standpipe   8776      functional
# 2         communal standpipe  34310      functional
# 3         communal standpipe  67743  non functional
# 4         communal standpipe  19728      functional
# ...                      ...    ...             ...
# 59395     communal standpipe  60739      functional
# 59396     communal standpipe  27263      functional
# 59397              hand pump  37057      functional
# 59398              hand pump  31282      functional
# 59399              hand pump  26348      functional
#
# [59400 rows x 42 columns]

# %%
df = pd.concat([X, target], axis=1)
fig, ax = plt.subplots(figsize=(10,8))
sns.scatterplot(x='longitude', y='latitude', 
                hue='status_group', data=df, ax=ax)
plt.ylim(-12, 0)
plt.xlim(28, 42)
plt.legend(loc='lower left')

# %%
fig, ax = plt.subplots(figsize=(12,12))
sns.scatterplot(x='latitude', y='longitude', 
                hue='extraction_type', data=df, ax=ax)
plt.xlim(-12, 0)
plt.ylim(28, 42)
# Out:
# (28.0, 42.0)

# %%
fig, ax = plt.subplots(figsize=(12,12))
sns.scatterplot(x='latitude', y='longitude', hue='gps_height', palette='Blues', alpha=0.7, data=df, ax=ax)
sns.scatterplot(x='latitude', y='longitude', 
                hue='status_group', alpha=0.3, data=df, ax=ax)
plt.xlim(-12, 0)
plt.ylim(28, 42)
# Out:
# (28.0, 42.0)

# %%
df.head().drop([1,3])
# Out:
#   date_recorded        funder  gps_height     installer  longitude  latitude  \
# 0    2011-03-14         Roman        1390         Roman  34.938093 -9.856322
# 2    2013-02-25  Lottery Club         686  World vision  37.460664 -3.821329
# 4    2011-07-13   Action In A           0       Artisan  31.130847 -1.825359
#
#       wpt_name  region_code  district_code  population  ... extraction_type  \
# 0         none           11              5         109  ...         gravity
# 2  Kwa Mahundi           21              4         250  ...         gravity
# 4      Shuleni           18              1           0  ...         gravity
#
#   management management_group  payment_type quality_group  quantity  \
# 0        vwc       user-group      annually          good    enough
# 2        vwc       user-group    per bucket          good    enough
# 4      other            other     never pay          good  seasonal
#
#                  source source_class waterpoint_type_group status_group
# 0                spring  groundwater    communal standpipe   functional
# 2                   dam      surface    communal standpipe   functional
# 4  rainwater harvesting      surface    communal standpipe   functional
#
# [3 rows x 24 columns]

# %% [markdown]
# # Testing out

# %%
import pickle
def save_data(data, name):
    with open(name, 'wb') as f:
        pickle.dump(data, f)

def load_data(name):
    with open(name, 'rb') as f:
        return pickle.load(f)

# %%
df = load_data('dataframe_model_2')
X = df.drop(columns=['status_group'], axis=1)
y = df['status_group']

# %%
model_rf = load_data('model_rf_3')

# %%
df
# Out:
#        gps_height  longitude   latitude  wpt_name  region_code  district_code  \
# 0            1390  34.938093  -9.856322     False           11              5
# 1             686  37.460664  -3.821329      True           21              4
# 2             263  38.486161 -11.155298      True           90             63
# 3               0  31.130847  -1.825359      True           18              1
# 4               0  39.172796  -4.765587      True            4              8
# ...           ...        ...        ...       ...          ...            ...
# 51822        1210  37.169807  -3.253847      True            3              5
# 51823        1212  35.249991  -9.070629      True           11              4
# 51824           0  34.017087  -8.750434      True           12              7
# 51825           0  35.861315  -6.378573      True            1              4
# 51826         191  38.104048  -6.747464      True            5              2
#
#        population public_meeting scheme_management permit  ...  \
# 0             109           True               VWC  False  ...
# 1             250           True               VWC   True  ...
# 2              58           True               VWC   True  ...
# 3               0           True               NaN   True  ...
# 4               1           True               VWC   True  ...
# ...           ...            ...               ...    ...  ...
# 51822         125           True       Water Board   True  ...
# 51823          56           True               VWC   True  ...
# 51824           0           True               VWC  False  ...
# 51825           0           True               VWC   True  ...
# 51826         150           True               VWC   True  ...
#
#          status_group funder_perc_func funder_perc_repair  \
# 0          functional         0.821168           0.032847
# 1          functional         1.000000           0.000000
# 2      non functional         0.588878           0.096326
# 3          functional         1.000000           0.000000
# 4          functional         0.806667           0.000000
# ...               ...              ...                ...
# 51822      functional         0.881967           0.001639
# 51823      functional         1.000000           0.000000
# 51824      functional              NaN                NaN
# 51825      functional         1.000000           0.000000
# 51826      functional         0.406324           0.075889
#
#       funder_perc_non_func installer_perc_func installer_perc_repair  \
# 0                 0.145985            0.602151              0.075269
# 1                 0.000000            0.660326              0.130435
# 2                 0.314796            0.584158              0.044554
# 3                 0.000000            0.573770              0.040984
# 4                 0.193333            0.550926              0.081494
# ...                    ...                 ...                   ...
# 51822             0.116393            0.881967              0.001639
# 51823             0.000000            1.000000              0.000000
# 51824                  NaN                 NaN                   NaN
# 51825             0.000000            0.600000              0.000000
# 51826             0.517787            0.487603              0.132231
#
#       installer_perc_non_func perc_func_nearby perc_on_func_nearby  \
# 0                    0.322581            78.45               18.97
# 1                    0.209239            51.54               40.38
# 2                    0.371287            30.34               69.66
# 3                    0.385246            59.85               34.75
# 4                    0.367580            65.22               34.78
# ...                       ...              ...                 ...
# 51822                0.116393            75.36               20.72
# 51823                0.000000            63.79               33.91
# 51824                     NaN            60.43               20.05
# 51825                0.400000            38.36               56.60
# 51826                0.380165            59.29               37.61
#
#       perc_repair_nearby
# 0                   2.59
# 1                   8.08
# 2                   0.00
# 3                   5.41
# 4                   0.00
# ...                  ...
# 51822               3.91
# 51823               2.30
# 51824              19.52
# 51825               5.03
# 51826               3.10
#
# [51827 rows x 33 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
import sklearn.metrics as metrics

def evaluate_clf_model(model,X_train, y_train, X_test,y_test,classes=None,
                           normalize='true',cmap='Purples', label=''):
    """Accepts an sklearn-compatible classification model + test data 
    and displays several sklearn.metrics functions: 
    - classifciation_report
    - plot_confusion_matrix
    - 
    - plot_roc_curve
    """
     
    ## Get Predictions
    y_hat_train = model.predict(X_train)
    y_hat_test = model.predict(X_test)
    
    print('---'*20)
    print('Train Accuracy : ', round(metrics.accuracy_score(y_train, y_hat_train),2))
    print('Test Accuracy : ', round(metrics.accuracy_score(y_test, y_hat_test),2))
    print('---'*20)
    ## Classification Report / Scores 
    table_header = "[i] CLASSIFICATION REPORT"
    
    ## Add Label if given
    if len(label)>0:
        table_header += f" {label}"
        
    
    ## PRINT CLASSIFICATION REPORT
    dashes = '---'*20
    print(dashes,table_header,dashes,sep='\n')

    print(metrics.classification_report(y_test,y_hat_test,
                                    target_names=classes))
    
    report = metrics.classification_report(y_test,y_hat_test,
                                               target_names=classes,
                                          output_dict=True)
    print(dashes+"\n\n")
    
    

    ## MAKE FIGURE
    fig, axes = plt.subplots(figsize=(10,4))#,ncols=2)
    
    ## Plot Confusion Matrix 
    metrics.plot_confusion_matrix(model, X_test,y_test,
                                  display_labels=classes,
                                  normalize=normalize,
                                 cmap=cmap,ax=axes)
    axes.set(title='Confusion Matrix')
    
    ## Plot Roc Curve
#     roc_plot = metrics.plot_roc_curve(model, X_test, y_test,ax=axes[1])
#     axes[1].legend()
#     axes[1].plot([0,1],[0,1],ls=':')
#     axes[1].grid()
#     axes[1].set_title('Receiving Operator Characteristic (ROC) Curve') 
    fig.tight_layout()
    plt.show()
    
    return report, fig, axes
